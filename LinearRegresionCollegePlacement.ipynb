# %% [markdown]
# <a href="https://colab.research.google.com/github/denztivoh/Decision-making/blob/main/LinearRegresionCollegePlacement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("Study Hour(Linear Regression).csv")

# %%
data
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
data.isnull().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# visualization | ploting

# %%
x=data.drop("Scores", axis=1)
y=data["Scores"]

# %%
x
# Out:
#     Hours
# 0     2.5
# 1     5.1
# 2     3.2
# 3     8.5
# 4     3.5
# 5     1.5
# 6     9.2
# 7     5.5
# 8     8.3
# 9     2.7
# 10    7.7
# 11    5.9
# 12    4.5
# 13    3.3
# 14    1.1
# 15    8.9
# 16    2.5
# 17    1.9
# 18    6.1
# 19    7.4
# 20    2.7
# 21    4.8
# 22    3.8
# 23    6.9
# 24    7.8

# %%
y
# Out:
# 0     21
# 1     47
# 2     27
# 3     75
# 4     30
# 5     20
# 6     88
# 7     60
# 8     81
# 9     25
# 10    85
# 11    62
# 12    41
# 13    42
# 14    17
# 15    95
# 16    30
# 17    24
# 18    67
# 19    69
# 20    30
# 21    54
# 22    35
# 23    76
# 24    86
# Name: Scores, dtype: int64

# %%
plt.scatter(x,y)
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.title("Hours vs Scores")
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3, random_state=2)

# %%
x_train
# Out:
#     Hours
# 12    4.5
# 22    3.8
# 4     3.5
# 10    7.7
# 5     1.5
# 19    7.4
# 1     5.1
# 2     3.2
# 7     5.5
# 21    4.8
# 20    2.7
# 18    6.1
# 11    5.9
# 24    7.8
# 13    3.3
# 15    8.9
# 8     8.3

# %%
y_train
# Out:
# 12    41
# 22    35
# 4     30
# 10    85
# 5     20
# 19    69
# 1     47
# 2     27
# 7     60
# 21    54
# 20    30
# 18    67
# 11    62
# 24    86
# 13    42
# 15    95
# 8     81
# Name: Scores, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
x_train = StandardScaler().fit_transform(x_train)
x_test = StandardScaler().fit_transform(x_test)

# %%
x_train
# Out:
# array([[-0.37694794],
#        [-0.70922058],
#        [-0.85162313],
#        [ 1.14201266],
#        [-1.80097351],
#        [ 0.9996101 ],
#        [-0.09214283],
#        [-0.99402569],
#        [ 0.09772724],
#        [-0.23454539],
#        [-1.23136328],
#        [ 0.38253236],
#        [ 0.28759732],
#        [ 1.18948018],
#        [-0.94655817],
#        [ 1.71162289],
#        [ 1.42681777]])

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print( lr.intercept_ )
print( lr.coef_ )
# Out:
# 54.76470588235294
# [21.96842762]

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, lr.predict(x_train), color = "red")
plt.title("Hours vs Scores ")
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.show()

# %%
y_pred=lr.predict(x_test)

# %%
y_test
# Out:
# 14    17
# 0     21
# 17    24
# 6     88
# 23    76
# 9     25
# 3     75
# 16    30
# Name: Scores, dtype: int64

# %%
y_pred
# Out:
# array([30.7319544 , 40.88919276, 36.53609061, 89.4988335 , 72.8119419 ,
#        42.34022681, 84.42021431, 40.88919276])

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
print( "RMSE: ",np.sqrt( mean_squared_error( y_test, y_pred ) ))
print( "R-squared: ",r2_score( y_test, y_pred ) )
# Out:
# RMSE:  12.558407378815621
# R-squared:  0.7943089717739933

# %%
hour=[[7.5]]
lr.predict(hour)
# Out:
# array([219.52791303])
